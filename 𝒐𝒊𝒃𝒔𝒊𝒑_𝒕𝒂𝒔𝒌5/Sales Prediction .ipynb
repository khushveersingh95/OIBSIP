# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Advertising.csv')

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
import seaborn as sns

# %%
sns.scatterplot(x='Radio',y='Sales',data=df)
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
sns.scatterplot(x='TV',y='Sales',data=df)
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
sns.scatterplot(x='Newspaper',y='Sales',data=df)
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.sample(5)
# Out:
#         TV  Radio  Newspaper  Sales
# 163  163.5   36.8        7.4   18.0
# 188  286.0   13.9        3.7   15.9
# 192   17.2    4.1       31.6    5.9
# 134   36.9   38.6       65.6   10.8
# 83    68.4   44.5       35.6   13.6

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 sns.heatmap(df.corr(),annot=True)
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
df.corr()

# tv is highly corelated with sales

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df['TV'] = df['TV'].astype(int)
df['Radio'] = df['Radio'].astype(int)
df['Newspaper'] = df['Newspaper'].astype(int)

# %%
df.head(5)
# Out:
#     TV  Radio  Newspaper  Sales
# 0  230     37         69   22.1
# 1   44     39         45   10.4
# 2   17     45         69    9.3
# 3  151     41         58   18.5
# 4  180     10         58   12.9

# %%
import matplotlib.pylab as plt

# %%
plt.hist(df['TV'],bins=20)
plt.xlabel("TV")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
plt.hist(df['Radio'],bins=20)
plt.xlabel("Radio")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
plt.hist(df['Newspaper'],bins=20)
plt.xlabel("Newspaper")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
sns.pairplot(df,hue=None)
# Out:
# C:\Users\singh\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\singh\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\singh\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.distplot(df['Radio'])
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_20464\2532850109.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Radio'])
# C:\Users\singh\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Radio', ylabel='Density'>

# %%
sns.distplot(df['Newspaper'])
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_20464\3262100579.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Newspaper'])
# C:\Users\singh\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Newspaper', ylabel='Density'>

# %%
sns.distplot(df['TV'])
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_20464\2926773584.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['TV'])
# C:\Users\singh\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='TV', ylabel='Density'>

# %%
x=df[['TV','Radio','Newspaper']]
y=df['Sales']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
ypred = lr.predict(x_test)

# %%
lr.score(x_test,y_test)
# Out:
# 0.8998774499187092

# %%
from sklearn.metrics import mean_squared_error

# Assuming you have predicted values in 'y_pred' and actual values in 'y_test'
mse = mean_squared_error(y_test, ypred)
print("Mean Squared Error (MSE):", mse)
# Out:
# Mean Squared Error (MSE): 3.1602274959798913

# %%
# check negative value because log transform not apply in negative value
y=[]
for i in df['Radio']:
    if i<0:
       y.append(i)
# print(y)        
N=[]
for i in df['Newspaper']:
    if i<0:
       N.append(i)
# print(N) 

t=[]
for i in df['TV']:
    if i<0:
       t.append(i)
print(t)
# Out:
# []

# %%
# we should apply log transformer for right skewd data and it is not apply on negative value
# and for left skwed data we apply sqr tansformer
from sklearn.preprocessing import PowerTransformer

# %%
transformer = PowerTransformer(method="yeo-johnson")

# %%
df['Newspaper']= transformer.fit_transform(df[['Newspaper']])
df['TV']= transformer.fit_transform(df[['TV']])

# %%
sns.distplot(df['TV'])
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_20464\2926773584.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['TV'])
# C:\Users\singh\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='TV', ylabel='Density'>

# %%
df.skew() 
# we checking data distribution
# Out:
# TV          -0.321356
# Radio        0.096392
# Newspaper   -0.081409
# Sales        0.407571
# dtype: float64

# %%
x=df[['TV','Radio','Newspaper']]
y=df['Sales']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
ypred = lr.predict(x_test)

# %%
x_test.head(3)
# Out:
#           TV  Radio  Newspaper
# 95  0.271407     31   1.029186
# 15  0.604231     47   1.029186
# 30  1.534943     28   0.728457

# %%
ypred
# Out:
# array([16.75196168, 21.11846924, 21.092497  ,  9.71726211, 22.24062197,
#        13.49529856, 21.09217233,  7.42523016, 13.59184444, 15.45613524,
#         8.63674358,  6.66243621, 14.27799538,  7.66681295, 10.08814068,
#        12.39205932,  7.8174199 , 16.45427978, 10.5583833 , 18.74675034,
#        19.62159697, 13.40402637, 12.22968377, 21.17309623,  7.9092314 ,
#         5.88602658, 20.99905001, 12.30159877,  9.40975391,  7.49855538,
#        12.54775006, 10.18677258, 21.64183321, 11.56642468, 17.7693967 ,
#        20.07576149, 14.14290054, 20.45402653, 11.28020323,  4.10590996])

# %%
lr.score(x_test,y_test)
# Out:
# 0.9235994383402837

# %%
from sklearn.metrics import mean_squared_error

# Assuming you have predicted values in 'y_pred' and actual values in 'y_test'
mse = mean_squared_error(y_test, ypred)
print("Mean Squared Error (MSE):", mse)
# Out:
# Mean Squared Error (MSE): 2.4114762904991105

# %%
lr.coef_
# Out:
# array([3.91094115, 0.19155319, 0.08785847])

# %%
lr.intercept_
# Out:
# 9.661933286347416

# %%
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(lr,x,y, cv=5)

# Print the cross-validation scores
print("Cross-Validation Scores:", cv_scores)
# Out:
# Cross-Validation Scores: [0.90005046 0.93757146 0.92851553 0.87152586 0.90322832]
